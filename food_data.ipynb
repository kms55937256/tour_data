# %%
import pandas as pd

# 1) 엑셀 읽기 (앞의 3줄 건너뛰기)
df = pd.read_excel("data/전국맛집.xlsx", skiprows=3)

# 2) CSV로 저장
df.to_csv("data/전국맛집.csv", index=False, encoding="utf-8-sig")

print("✅ CSV 파일로 저장 완료!")
# Out:
# ✅ CSV 파일로 저장 완료!

# %%
import pandas as pd

df = pd.read_csv("data/전국맛집.csv", encoding="utf-8-sig")
print(df.head())
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4   Unnamed: 5  \
# 0         지역        도시명       음식종류       대표메뉴         식당상호       포털 검색명
# 1        강원도         강릉        매운탕     망치 매운탕         시골식당      강릉 시골식당
# 2        강원도         강릉   멍게비빔밥/물회      멍게비빔밥      제주 해인물회     강릉제주해인물회
# 3        강원도         강릉         분식         분식  여고시절 카레 떡볶이  여고시절 카레 떡볶이
# 4        강원도         강릉         분식         분식         옛빙그레         옛빙그레
#
#                                           Unnamed: 6
# 0                                               추천사유
# 1  강원도도 동해안에서만 나는 망치어종으로 만든 매운탕이며 시원한맛과 밑반찬인 오징어 ...
# 2  해녀출신 사장님이 직접 멍게를 숙성하여 전복과 어울어진 비빔밥과 물회가 유명한 맛집...
# 3                   학창시절의 추억을 떠오르게 하는 분식집(가격이 많이 오름)
# 4                                      쫄사리와 김밥이 맛있는집

# %%
df.columns = ['지역', '도시명', '음식종류', '대표메뉴', '식당상호', '포털 검색', '추천사유']
df
# Out:
#        지역  도시명      음식종류           대표메뉴         식당상호        포털 검색  \
# 0      지역  도시명      음식종류           대표메뉴         식당상호       포털 검색명
# 1     강원도   강릉       매운탕         망치 매운탕         시골식당      강릉 시골식당
# 2     강원도   강릉  멍게비빔밥/물회          멍게비빔밥      제주 해인물회     강릉제주해인물회
# 3     강원도   강릉        분식             분식  여고시절 카레 떡볶이  여고시절 카레 떡볶이
# 4     강원도   강릉        분식             분식         옛빙그레         옛빙그레
# ..    ...  ...       ...            ...          ...          ...
# 820  충청북도   충주        한식      메밀 새싹 막국수   원조 중앙탑 막국수   원조 중앙탑 막국수
# 821  충청북도  충주시        한식  송어 비빔회,쏘가리매운탕         금릉가든         금릉가든
# 822  충청북도  충주시        한식          꿩샤브샤브        대장군식당        대장군식당
# 823  충청북도  충주시        한식      메밀 새싹 막국수   원조 중앙탑 막국수   원조 중앙탑 막국수
# 824  충청북도  충주시        한식        자연산버섯전골       흥부와놀부네       흥부와놀부네
#
#                                                   추천사유
# 0                                                 추천사유
# 1    강원도도 동해안에서만 나는 망치어종으로 만든 매운탕이며 시원한맛과 밑반찬인 오징어 ...
# 2    해녀출신 사장님이 직접 멍게를 숙성하여 전복과 어울어진 비빔밥과 물회가 유명한 맛집...
# 3                     학창시절의 추억을 떠오르게 하는 분식집(가격이 많이 오름)
# 4                                        쫄사리와 김밥이 맛있는집
# ..                                                 ...
# 820  한반도의 중심을 상징하는 중앙탑\n중앙탑을 방문하신분들이 꼭 방문하신다는  시원한 ...
# 821                     충청북도의 지역특성상 민물생선요리가 유명하고 맛도 일품
# 822                충주시 수안보 지역 특색 맛집으로 일반음식이 아닌 꿩요리 전문점
# 823  후라이드 통닭과 함께 먹는 색 다른 막국수. 새싹의 아삭함과 메밀 막국수의 면이 맛...
# 824                       직접 캔 자연산 버섯 10가지로 만든 특별한 건강식
#
# [825 rows x 7 columns]

# %%
df['지역'].value_counts()
# Out:
# 지역
# 경기도      216
# 서울특별시    103
# 제주도       65
# 충청남도      63
# 강원도       57
# 경상남도      51
# 대구광역시     48
# 전라북도      45
# 부산광역시     39
# 경상북도      33
# 인천광역시     33
# 전라남도      29
# 충청북도      20
# 광주광역시     15
# 울산광역시      3
# 대전광역시      3
# 충청남도       1
# 지역         1
# Name: count, dtype: int64

# %%
gang_df = df.loc[df['지역'] == '제주도']

gang_df['도시명'].value_counts()
# Out:
# 도시명
# 제주시     41
# 서귀포시    24
# Name: count, dtype: int64

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import seaborn as sns

# %%
font_path = 'C:\\Windows\\Fonts\\malgun.ttf'

font_prop = fm.FontProperties(fname=font_path).get_name()
print(font_prop)

matplotlib.rc('font', family=font_prop)
# Out:
# Malgun Gothic

# %%
figure, axes1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(8,4)

sns.countplot(data=gang_df, x='도시명', ax=axes1, order=gang_df['도시명'].value_counts().index, hue='도시명')

plt.title("강원도지역의 도시별 맛집 수")
plt.show()

# %%
food_kind = gang_df['음식종류'].value_counts(normalize=True)
food_kind
# Out:
# 음식종류
# 한식           0.846154
# 일식           0.061538
# 중식           0.030769
# 양식           0.015385
# 백반           0.015385
# 퓨전           0.015385
# 이탈리안 레스토랑    0.015385
# Name: proportion, dtype: float64

# %%
figure = plt.figure(figsize=(20,12))

plt.pie(food_kind, labels=food_kind.index, autopct='%1.1f%%', startangle=95,shadow=True)

plt.axis('equal')
plt.title("제주도지역의 음식종류 맛집 수")
plt.show()
